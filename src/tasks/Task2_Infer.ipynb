# %% [markdown]
# # Task 2 – Inferencing: Linker Length vs. Pore Size
#
# In this notebook, we test whether a knowledge graph-augmented LLM can infer scientific relationships between structural features and material properties.
#
# The LLM is provided with real examples retrieved from the knowledge graph — specifically, MOFs with known linker lengths and pore sizes. Rather than memorizing trends, the LLM is prompted to reason from these examples and infer the relationship between linker length and pore size. This setup showcases the ability of KG-augmented models to support grounded scientific intuition.

# %% [markdown]
# ## Accessing the KG

# %%
from src.MOF_ChemUnity.Agents.QueryAgent import QueryGenerationAgent
import pandas as pd

# %%
# Connect to graph
agent = QueryGenerationAgent()
data = agent.run_full_query("List 30 MOFs with their names (every name delimited by <|>), smiles linker, pore size, and water stability. Only include MOFs with a value for each field")
# Out:
# ✅ Successfully connected to the Neo4j database.
#    m.refcode                                          mof_names  \
# 0     CELZIE                                    3<|>CAU-10-OCH3
# 1     ESIGES                                             NTHU-2
# 2     YATDUV                     NH4@ZnPzC<|>NH4Â·Zn3OHÂ­(PzC)3
# 3     QOVDEL      Ni-STA-12<|>St Andrews nanoporous material-12
# 4     QOVDAH                          Ni-STA-12 (hydrated form)
# 5     SISZEC  [Cd3(C8H3SO7)2(C10H8N4)3(C3H7NO)2](C3H7NO)2Â·(...
# 6     OJAWII          Fe-ICR-6<|>Fe-ICR-2<|>Fe-ICR-4<|>Fe-ICR-7
# 7   KETHEY01                       compound 1<|>[Cd(pyip)(dmf)]
# 8     CIKCOQ                       compound 2<|>[Cd(pyip)(doa)]
# 9     GEDTAM                                              UCY-2
# 10    KADLOT   2<|>[(Cu2I2)Â­Cu2(C11H7N2O2)4]Â·(DMF)7.4(H2O)4.6
# 11    NOFQIK                                   TCuI<|>TMBPÂ·CuI
# 12    QEFNAQ                   [Cu(pymo)2]Â·NH4ClO4<|>1Â·NH4ClO
# 13    JESTIN         1<|>{[Cd2(sdb)2(pcih)2]Â·2DMFÂ·H2O}<|>1H2O
# 14    KOHKIC  1<|>[Na0.5Zn4.75(m3-OH)2(BTB)2(HBTB)(H2O)0.5]5...
# 15    NADKEK                               Structure 2<|>STA-13
# 16    PELRIJ                               1<|>[Cu3(L1)2(H2O)3]
# 17    NABMUA                      Mg-MOF-1<|>[Mg(3,5-PDC)(H2O)]
# 18    XULFEQ    compound 1<|>[Zn4(btc)2(4-bph)(H2O)4]nÂ·2n(H2O)
# 19    VUGWUR    compound 1<|>[La(TTTPC)(O)2(NO2)2(Cl)]Â·(H2O)10
# 20    HICVOG          complex 1<|>1a<|>{[Zn2(bpt)(btc)]Â·4H2O}n
# 21    LUDLED                   compound 1<|>HKUST-1<|>Cu3(BTC)2
# 22    GUVBOQ           compound 1<|>[Zn9IJOH)2L6]IJH3O)2IJH2O)6
# 23    RIRDIH                                          Co-ZIF-81
# 24    RIRDED                                          Co-ZIF-69
# 25    AVILEY                                      Ir-PMOF-1(Hf)
# 26    ZUCKIT     POST-66(Y)<|>POST-66(Y)-wt<|>POST-66(Y)-wt-24h
# 27    MUMLIR         Compound 1<|>1a<|>[Zn3(HL)2(fma)2]$DMA$H2O
# 28    QODJEB                 3<|>compound 3<|>[Zn2(pypz)2(bdc)]
# 29    FEWTUY                 compound 3<|>[Ni5(OH2)3(4-pyc)10]n
#
#                                         smiles_linker  \
# 0                ['COc1cc(cc(c1)C(=O)[O-])C(=O)[O-]']
# 1   ['[O-]C(=O)c1ccc(cc1)C(=O)[O-]', '[O]P(=O)(O)[...
# 2   ['[O-]C(=O)C1=CN=N[CH]1', '[O-]C(=O)C1=C[N]N=C1']
# 3   ['[O]P(=O)([C]N1[C][C]N([C][C]1)[C]P(=O)([O])[...
# 4   ['[O]P(=O)([C]N1[C][C]N([C][C]1)[C]P(=O)([O])[...
# 5   ['[O-]C(=O)c1cc(cc(c1)S([O])([O])[O])C(=O)[O-]...
# 6   ['[O]P(=O)(c1ccccc1)c1ccc(cc1)c1ccc(cc1)P(=O)(...
# 7          ['[O-]C(=O)c1cc(cc(c1)c1ccncc1)C(=O)[O-]']
# 8          ['[O-]C(=O)c1cc(cc(c1)c1ccncc1)C(=O)[O-]']
# 9   ['[O-]C(=O)c1ccc(cc1)[CH][N]c1cc(cc(c1)C(=O)[O...
# 10  ['[O-]C(=O)c1ccc(cc1)C1=C[N]C=N[CH]1', '[O-]C(...
# 11             ['Cc1[nH][n-]c(c1c1c(C)[n-][nH]c1C)C']
# 12                                ['O=[C]1=NC=CC=N1']
# 13  ['O=C(c1ccncc1)NN=Cc1ccncc1', '[O-]C(=O)c1ccc(...
# 14  ['[O-]C(=O)c1ccc(cc1)c1cc(cc(c1)c1ccc(cc1)C(=O...
# 15  ['[C][C]1N([C][C]N([C]1[C])[C]P(=O)([O])[O])[C...
# 16  ['O=C(c1cc(cc(c1)C(=O)Nc1ccc(cc1)C(=O)[O-])C(=...
# 17                   ['[O-]C(=O)c1cncc(c1)C(=O)[O-]']
# 18  ['O=C(c1ccncc1)[N][N]C(=O)c1ccncc1', '[O-]C(=O...
# 19  ['[O-]C(=O)C1=C[CH]N(C=C1)Cc1c(C)c(CN2[CH]C=C(...
# 20  ['[O-]C(=O)c1cc(cc(c1)C(=O)[O-])C(=O)[O-]', 'n...
# 21        ['[O-]C(=O)c1cc(cc(c1)C(=O)[O-])C(=O)[O-]']
# 22  ['[O-]C(=O)[C]1C(=CC(=CC1=O)c1cc(cc(c1)c1cc(O)...
# 23  ['Brc1cc2N=C[N]c2cc1Br', 'O=N(=O)C1=NC=C[N]1',...
# 24  ['Clc1cc2N=C[N]c2cc1Cl', 'O=N(=O)C1=NC=C[N]1',...
# 25  ['[O-]C(=O)c1ccc(cc1)C1=C2C=CC3=[N]2[Ir]24(n5c...
# 26  ['[O-]C(=O)c1ccc2-c3c(C(c2c1)(C)C)c1-c2ccc(cc2...
# 27  ['[O-]C(=O)C=CC(=O)[O-]', 'n1ccn(c1)c1ccc(cc1)...
# 28  ['[O-]C(=O)c1ccc(cc1)C(=O)[O-]', 'n1ccc(cc1)C1...
# 29                              ['[O-]C(=O)c1ccncc1']
#
#                                         pore_size water_stability
# 0                                             2.5          Stable
# 1                                      1.36, 21.8        Unstable
# 2                                               1        Unstable
# 3                                               1          Stable
# 4                                               1          Stable
# 5                                       5.0 × 8.0          Stable
# 6                                            2.16        Unstable
# 7                                       8.2 x 8.2          Stable
# 8   8.0 × 11.3, 7.3 × 11.3, 7.3 × 10.2, 7.3 × 5.1          Stable
# 9                                             3-4          Stable
# 10                                              9          Stable
# 11                                            5.2          Stable
# 12                                            8.1        Unstable
# 13                                            4.4          Stable
# 14                                            6.0        Unstable
# 15                                              3          Stable
# 16                                           21.4        Unstable
# 17                                            4.0          Stable
# 18                                            3.8          Stable
# 19                                            7.5          Stable
# 20                                            4.1          Stable
# 21                                           5.85          Stable
# 22                                       Around 1          Stable
# 23                                            6.2          Stable
# 24                                            7.9          Stable
# 25                                            1.6          Stable
# 26                                   3.8 and 13.9        Unstable
# 27                                      8.8 - 8.8        Unstable
# 28                                            1.6        Unstable
# 29                                           0.90        Unstable

# %% [markdown]
# ## Responses

# %% [markdown]
# First, here is the question both LLM's will be seeing

# %%
question = "How does pore diameter and linker length affect the water stability of MOFs?"

# %% [markdown]
# ### Graph-RAG Enabled GPT-4o

# %%
# Auto-format RAG prompt from a DataFrame
def generate_few_shot_prompt(data, question, max_examples=12):
    # Limit to first N examples
    subset = data.head(max_examples)

    # Start with task-agnostic intro
    lines = ["Here are some MOFs with their associated properties:"]

    for _, row in subset.iterrows():
        props = []
        for col in data.columns:
            if "refcode" in col.lower():
                continue  # skip any column containing 'refcode'
            value = row[col]
            value_str = str(value).strip()
            if value_str.startswith('[') and value_str.endswith(']'):
                value_str = value_str[1:-1]  # remove brackets
            props.append(f"{col} = {value_str}")
        lines.append("- " + ", ".join(props))

    context = "\n".join(lines)
    rag_prompt = f"{context}\n\nUse the examples above to help answer the following question:\n{question.strip()}"
    return rag_prompt


# Now use the function to generate the prompt
rag_prompt = generate_few_shot_prompt(data, question)
print(rag_prompt)
# Out:
# Here are some MOFs with their associated properties:
# - mof_names = 3<|>CAU-10-OCH3, smiles_linker = 'COc1cc(cc(c1)C(=O)[O-])C(=O)[O-]', pore_size = 2.5, water_stability = Stable
# - mof_names = NTHU-2, smiles_linker = '[O-]C(=O)c1ccc(cc1)C(=O)[O-]', '[O]P(=O)(O)[O]', pore_size = 1.36, 21.8, water_stability = Unstable
# - mof_names = NH4@ZnPzC<|>NH4Â·Zn3OHÂ­(PzC)3, smiles_linker = '[O-]C(=O)C1=CN=N[CH]1', '[O-]C(=O)C1=C[N]N=C1', pore_size = 1, water_stability = Unstable
# - mof_names = Ni-STA-12<|>St Andrews nanoporous material-12, smiles_linker = '[O]P(=O)([C]N1[C][C]N([C][C]1)[C]P(=O)([O])[O])[O]', pore_size = 1, water_stability = Stable
# - mof_names = Ni-STA-12 (hydrated form), smiles_linker = '[O]P(=O)([C]N1[C][C]N([C][C]1)[C]P(=O)([O])[O])[O]', pore_size = 1, water_stability = Stable
# - mof_names = [Cd3(C8H3SO7)2(C10H8N4)3(C3H7NO)2](C3H7NO)2Â·(CH3OH)4<|>Compound I, smiles_linker = '[O-]C(=O)c1cc(cc(c1)S([O])([O])[O])C(=O)[O-]', 'n1ccc(cc1)[N][N]c1ccncc1', pore_size = 5.0 × 8.0, water_stability = Stable
# - mof_names = Fe-ICR-6<|>Fe-ICR-2<|>Fe-ICR-4<|>Fe-ICR-7, smiles_linker = '[O]P(=O)(c1ccccc1)c1ccc(cc1)c1ccc(cc1)P(=O)(c1ccccc1)[O]', pore_size = 2.16, water_stability = Unstable
# - mof_names = compound 1<|>[Cd(pyip)(dmf)], smiles_linker = '[O-]C(=O)c1cc(cc(c1)c1ccncc1)C(=O)[O-]', pore_size = 8.2 x 8.2, water_stability = Stable
# - mof_names = compound 2<|>[Cd(pyip)(doa)], smiles_linker = '[O-]C(=O)c1cc(cc(c1)c1ccncc1)C(=O)[O-]', pore_size = 8.0 × 11.3, 7.3 × 11.3, 7.3 × 10.2, 7.3 × 5.1, water_stability = Stable
# - mof_names = UCY-2, smiles_linker = '[O-]C(=O)c1ccc(cc1)[CH][N]c1cc(cc(c1)C(=O)[O-])C(=O)[O-]', pore_size = 3-4, water_stability = Stable
# - mof_names = 2<|>[(Cu2I2)Â­Cu2(C11H7N2O2)4]Â·(DMF)7.4(H2O)4.6, smiles_linker = '[O-]C(=O)c1ccc(cc1)C1=C[N]C=N[CH]1', '[O-]C(=O)c1ccc(cc1)c1cncnc1', pore_size = 9, water_stability = Stable
# - mof_names = TCuI<|>TMBPÂ·CuI, smiles_linker = 'Cc1[nH][n-]c(c1c1c(C)[n-][nH]c1C)C', pore_size = 5.2, water_stability = Stable
#
# Use the examples above to help answer the following question:
# How does pore diameter and linker length affect the water stability of MOFs?

# %%
from openai import OpenAI
# Initialize client (uses OPENAI_API_KEY from .env automatically)
client = OpenAI()

# Send the prompt to GPT-4
response = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "You are a materials science expert."},
        {"role": "user", "content": rag_prompt}
    ],
    temperature=0.5  # slightly higher to allow some reasoning flexibility
)

# Extract and print the response
rag_answer = response.choices[0].message.content.strip()
print(rag_answer)
# Out:
# The water stability of Metal-Organic Frameworks (MOFs) is influenced by several factors, including pore diameter and linker length, as seen in the examples provided. Here's an analysis based on these factors:
#
# 1. **Pore Diameter**:
#    - **Smaller Pores**: MOFs with smaller pore diameters, such as NTHU-2 (1.36 Å), NH4@ZnPzC (1 Å), and Ni-STA-12 (1 Å), tend to be less stable in water. This may be due to the higher surface area to volume ratio, which can lead to increased interaction with water molecules, potentially destabilizing the framework.
#    - **Larger Pores**: In contrast, MOFs with larger pores, such as compound 1 (8.2 × 8.2 Å) and compound 2 (8.0 × 11.3 Å, etc.), are noted to be stable in water. Larger pores may facilitate better diffusion and less interaction per unit area with water, reducing the risk of framework collapse.
#
# 2. **Linker Length and Structure**:
#    - **Shorter Linkers**: Shorter and simpler linkers, such as those seen in unstable MOFs like NTHU-2 and Fe-ICR-6, might lead to less robust frameworks that are more susceptible to hydrolysis or other degradation mechanisms in the presence of water.
#    - **Longer or Complex Linkers**: MOFs with longer or more complex linkers, like those in stable MOFs such as compound 1 and compound 2, may provide additional stability. The complexity can contribute to increased rigidity and resistance to water-induced degradation.
#
# 3. **Chemical Composition**:
#    - The chemical nature of the linkers also plays a crucial role. Linkers that are more hydrophobic or have functional groups that can form strong interactions with the metal nodes (e.g., through hydrogen bonding or coordination) can enhance water stability.
#
# In summary, MOFs with larger pore sizes and longer or more complex linkers generally exhibit better water stability. However, the chemical nature of the linkers and the overall framework architecture are also critical factors that influence stability in aqueous environments.

# %% [markdown]
# ### Vanilla GPT-4o

# %%
# Send the prompt to GPT-4
response = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "You are a materials science expert."},
        {"role": "user", "content": question}
    ],
    temperature=0.5  # slightly higher to allow some reasoning flexibility
)

# Extract and print the response
vanilla_answer = response.choices[0].message.content.strip()
print(vanilla_answer)
# Out:
# The water stability of metal-organic frameworks (MOFs) is a critical consideration for their practical applications, particularly in environments where moisture is present. The pore diameter and linker length are two structural parameters that can significantly influence the water stability of MOFs.
#
# 1. **Pore Diameter:**
#
#    - **Larger Pore Diameters:** MOFs with larger pore diameters typically have a higher surface area exposed to water molecules. This can lead to increased hydrolytic degradation if the metal-ligand bonds are not inherently stable against water. Larger pores can also facilitate the ingress of water molecules, potentially accelerating the breakdown of the framework if it is not robust enough.
#
#    - **Smaller Pore Diameters:** Smaller pore diameters can limit the access of water molecules to the interior of the framework, potentially enhancing stability. However, this is highly dependent on the nature of the metal-ligand bonds and the overall framework stability. If the material is inherently unstable, smaller pores may not significantly improve water resistance.
#
# 2. **Linker Length:**
#
#    - **Longer Linkers:** Longer organic linkers can introduce more flexibility into the framework, which might affect stability under aqueous conditions. The increased flexibility can lead to structural distortions when interacting with water, potentially weakening the overall framework integrity. However, longer linkers can also allow for more extensive π-π stacking or other non-covalent interactions that might enhance stability in some cases.
#
#    - **Shorter Linkers:** Shorter linkers generally contribute to a more rigid framework, which can enhance stability against water-induced structural changes. The rigidity can help maintain the integrity of the framework in the presence of water, assuming the metal-ligand bonds are not prone to hydrolysis.
#
# In addition to pore size and linker length, the intrinsic stability of the metal-ligand bonds is crucial. MOFs constructed with high-valent metal ions (e.g., Zr(IV), Ti(IV), Al(III)) and strong, coordinatively saturated bonds tend to exhibit better water stability. The hydrophobicity of the organic linkers and the presence of hydrophobic functional groups can also play a significant role in enhancing water resistance.
#
# Overall, optimizing water stability involves a careful balance of pore size, linker length, and the selection of metals and linkers that provide robust, hydrolysis-resistant frameworks.
