# %% [markdown]
# # Task 4 - Retrieve: Has PCN-46 ever been used for Carbon Capture?
# In this notebook, we demonstrate the ability of knowledge graph-augmented LLMs to conduct an advanced literature search. By combining the pre-existing information in our knowledge graph, we have identified a promising MOF candidate for Carbon Capture (PCN-46) based on its similarity to HKUST-1, experimentally measured CO2 uptake, and text-mined expert recommendation. Now, we will use a cross-document agent to search for additional information outside of PCN-46's original synthesis paper

# %%
from MOF_ChemUnity.QueryAgent import QueryGenerationAgent

# Connect to graph
agent = QueryGenerationAgent()
data = agent.run_full_query("All experimental information for MOFs with name PCN-46 and HKUST-1")
# Out:
# ✅ Connected to Neo4j.
#    m.refcode                 property_name  \
# 0     LUYHAP                       Density
# 1     LUYHAP     Solvent-Accessible Volume
# 2     LUYHAP                   Pore Volume
# 3     LUYHAP                  Surface Area
# 4     LUYHAP                    CO2 Uptake
# 5     LUYHAP                     H2 uptake
# 6     TISPAO                       Density
# 7     TISPAO                  Surface Area
# 8     TISPAO                         Color
# 9     WULJUJ                       Density
# 10    WULJUJ                  Surface Area
# 11    WULKAQ                       Density
# 12    WULKAQ                  Surface Area
# 13    YOZNAE                       Density
# 14    YOZNAE                   Pore Volume
# 15    UVIPIZ         Coordination Geometry
# 16    UVIPIZ                       Density
# 17    UVIPIZ                   Pore Volume
# 18    UVIPIZ               Water Stability
# 19    ZACHIX                       Density
# 20    ZACHIX             Thermal Stability
# 21    ZACHIX       Magnetic Susceptibility
# 22    LUDLED                       Density
# 23    LUDLED                 Pore Diameter
# 24    LUDLED               Water Stability
# 25    BODPAN                   Cell Volume
# 26    BODPAN                       Density
# 27    BODPAN                   Pore Volume
# 28    BODPAN                  Surface Area
# 29    BODPAN               Water Stability
# 30    OQIZUL                Crystal System
# 31    OQIZUL                   Space Group
# 32    OQIZUL                   Cell Volume
# 33    OQIZUL                Formula Weight
# 34    OQIZUL                       Density
# 35    OQIZUL  Light Absorption Coefficient
# 36    OQIZUL             Thermal Stability
# 37    OQIZUL                  Surface Area
#
#                                        property_value        r.units  \
# 0                                            0.618537           None
# 1                                                73.8              %
# 2                                                 6.8              Å
# 3                                                2500         m2 g-1
# 4                                                21.0       mmol g-1
# 5                                                71.6         mg g-1
# 6                                             1.01627           None
# 7                                                  97           m²/g
# 8                                              Purple            NaN
# 9                                            0.880841          g/cm³
# 10                                               2095           m²/g
# 11                                           0.879538          g/cm3
# 12                                               2095           m2/g
# 13                                           0.882932           None
# 14                                      10.7, 12.7, 5              Å
# 15  Square pyramidal in hydrated, square planar in...            NaN
# 16                                           0.868575           None
# 17              Small pores 6 A, larger pores 11–15 A              A
# 18                                           Unstable            NaN
# 19                                           0.890304           None
# 20                                          30 to 400             °C
# 21                                             18.256  cm^3 mol^−1 K
# 22                                           0.881906           None
# 23                                               5.85              Å
# 24                                             Stable            NaN
# 25                                             144768             Å3
# 26                                           0.888078           None
# 27                                              0.709        cm3 g-1
# 28                                               1670         m2 g-1
# 29                                           Unstable            NaN
# 30                                              Cubic            NaN
# 31                                             F m-3m            NaN
# 32                                              18496             Å3
# 33                                            1566.48            NaN
# 34                                           0.868865          g/m−3
# 35                                              1.638           mm−1
# 36                                                280             °C
# 37                                                676           m2/g
#
#                                      r.condition                 r.reference  \
# 0                                           None                        None
# 1            Calculated using the PLATON routine            10.1039/c002767g
# 2             Based on the Horvath–Kawazoe model            10.1039/c002767g
# 3              Based on the N2 sorption isotherm            10.1039/c002767g
# 4         Saturation excess CO2 uptake at 30 bar            10.1039/c002767g
# 5                           Total uptake at 77 K            10.1039/c002767g
# 6                                           None                        None
# 7                     After sulfur encapsulation           10.1021/cg401304x
# 8                                After synthesis           10.1021/cg401304x
# 9                                  Not specified           10.1021/ja904782h
# 10                                 Not specified           10.1021/ja904782h
# 11                                 Not specified           10.1021/ja904782h
# 12                                 Not specified           10.1021/ja904782h
# 13                                          None                        None
# 14                                           NaN           10.1021/cm501138g
# 15              Interaction with water molecules          10.1039/c1cc12341f
# 16                                          None                        None
# 17             Structural description of HKUST-1          10.1039/c1cc12341f
# 18                                           NaN          10.1039/c1cc12341f
# 19                                          None                        None
# 20                         Under a nitrogen flow          10.1039/C5CE02074C
# 21                                      At 300 K          10.1039/C5CE02074C
# 22                                          None                        None
# 23                                           NaN          10.1039/c3nr04161a
# 24                                           NaN          10.1039/c3nr04161a
# 25                                     T = 100 K          10.1039/C4TA00138A
# 26                                          None                        None
# 27                                 Not specified          10.1039/C4TA00138A
# 28                                 Not specified          10.1039/C4TA00138A
# 29                                           NaN          10.1039/C4TA00138A
# 30                          Ambient temperature.  10.1016/j.poly.2016.06.039
# 31                          Ambient temperature.  10.1016/j.poly.2016.06.039
# 32                          Ambient temperature.  10.1016/j.poly.2016.06.039
# 33                          Ambient temperature.  10.1016/j.poly.2016.06.039
# 34                          Ambient temperature.  10.1016/j.poly.2016.06.039
# 35                          Ambient temperature.  10.1016/j.poly.2016.06.039
# 36           After pre-drying at 40°C in vacuum.  10.1016/j.poly.2016.06.039
# 37  Activated at 200°C under vacuum for 3 hours.  10.1016/j.poly.2016.06.039
#
#                                             r.summary
# 0                                                None
# 1   Calculated using the PLATON routine, PCN-46 ha...
# 2   It has a uniform pore size around 6.8 A˚ based...
# 3   Based on the N2 sorption isotherm, PCN-46 has ...
# 4   As can be seen in Fig. 5, the saturation exces...
# 5   Table 1 Ligand length, porosity and H2 uptake ...
# 6                                                None
# 7   As shown in Figure S2, Supporting Information,...
# 8     In fact, the HKUST-1/S mixture is still purple.
# 9             "HKUST-1 (2095) 201 177 23.4 0.21 19.3"
# 10  "HKUST-1, MOF-505, MOF-508, MIL-53, MOF-5, and...
# 11            "HKUST-1 (2095) 201 177 23.4 0.21 19.3"
# 12  "HKUST-1, MOF-505, MOF-508, MIL-53, MOF-5, and...
# 13                                               None
# 14  "Cuboctahedral pores are formed from 12 dinucl...
# 15  "Grajciar et al. showed that the Cu-Cu distanc...
# 16                                               None
# 17  "The HKUST-1 structure consists of three types...
# 18  Despite its interesting applications, one of t...
# 19                                               None
# 20  The TG curve of 1 exhibits three steps of weig...
# 21  In addition, the χmT value at 300 K is 18.256 ...
# 22                                               None
# 23  Like the small hydrophilic pore in STAM-1, in ...
# 24  Under ambient conditions, the crystal of HKUST...
# 25  Cubic space group Fm3c, T = 100 K, a = 52.508(...
# 26                                               None
# 27  Nitrogen sorption measurements of the HKUST-1 ...
# 28  Nitrogen sorption measurements of the HKUST-1 ...
# 29  HKUST-1 is classified as water-unstable (struc...
# 30  "Compound 1 crystallizes in the cubic crystal ...
# 31  "Compound 1 crystallizes in the cubic crystal ...
# 32                           "Volume | 18496(4) Å3 |"
# 33                       "Formula weight | 1566.48 |"
# 34                            "D calc | 1.125g/m−3 |"
# 35           "Absorption coefficient μ | 1.638mm−1 |"
# 36  "The de-solvated and guest-depleted 3D-network...
# 37  "The Brunauer–Emmett–Teller (BET) surface area...

# %% [markdown]
# ## Cross Document Extraction for PCN-46

# %%
import requests
import openai
import numpy as np
import pandas as pd
import faiss
import time  
import os

# %%
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()
# Retrieve the Scopus API key
SCOPUS_API_KEY = os.getenv('SCOPUS_API_KEY')

# %%
import requests
import pandas as pd
import time

def search_scopus(mof_name, count=50, batch_size=100, wait_time=1, abstract_wait=1):
    """
    Searches Scopus for articles related to the given MOF name and synthesis,
    retrieves metadata (Title, DOI), and fetches full abstracts.

    Parameters:
        mof_name (str): The name of the MOF to search for.
        count (int): The total number of papers to retrieve (default=50).
        batch_size (int): Max papers per request (Scopus limit = 200, using 100 for better control).
        wait_time (float): Delay (seconds) between Scopus search requests to avoid rate limits.
        abstract_wait (float): Delay (seconds) between abstract retrieval requests.

    Returns:
        pd.DataFrame: A DataFrame containing retrieved papers (Title, Abstract, DOI).
    """
    search_url = "https://api.elsevier.com/content/search/scopus"
    abstract_url_base = "https://api.elsevier.com/content/abstract/doi/"
    headers = {"X-ELS-APIKey": SCOPUS_API_KEY, "Accept": "application/json"}

    papers = []
    retrieved = 0  # Track total retrieved papers

    while retrieved < count:
        remaining = count - retrieved
        current_batch_size = min(batch_size, remaining)  # Ensure we don’t exceed count
        
        params = {
            "query": f'TITLE-ABS-KEY("{mof_name}" AND Carbon Capture) AND DOCTYPE(ar)',
            "count": current_batch_size,
            "start": retrieved
        }

        time.sleep(wait_time)  # Prevent hitting rate limits
        response = requests.get(search_url, headers=headers, params=params)

        if response.status_code != 200:
            print(f"Error: Received status code {response.status_code}")
            break  # Stop if error

        data = response.json()

        if "search-results" in data and "entry" in data["search-results"]:
            for entry in data["search-results"]["entry"]:
                title = entry.get("dc:title", "")
                doi = entry.get("prism:doi", "N/A")
                abstract = entry.get("dc:description", "") or "No abstract available"

                # Retrieve full abstract if missing
                if abstract == "No abstract available" and doi != "N/A":
                    time.sleep(abstract_wait)  # Prevent rate limits
                    abstract_url = f"{abstract_url_base}{doi}"
                    abstract_response = requests.get(abstract_url, headers=headers)
                    
                    if abstract_response.status_code == 200:
                        abstract_data = abstract_response.json()
                        abstract = abstract_data.get("abstracts-retrieval-response", {}).get("coredata", {}).get("dc:description", "No abstract available")

                papers.append({"title": title, "abstract": abstract, "doi": doi})
                retrieved += 1

                if retrieved >= count:
                    break  # Stop when we reach `count` papers

            if len(data["search-results"]["entry"]) < current_batch_size:
                break  # Stop if no more papers left in Scopus

        else:
            print("No results found or incorrect response format")
            break

    # Convert to DataFrame
    papers_df = pd.DataFrame(papers, columns=["title", "abstract", "doi"])

    if len(papers_df) < count:
        print(f"Warning: Could not find {count} papers. Returning {len(papers_df)} instead.")

    return papers_df

# %%
# Function to get OpenAI embeddings
def get_embedding(text, model="text-embedding-ada-002"):
    if not text.strip():  # Handle empty abstracts
        return np.zeros(1536)  # Default embedding size for OpenAI models
    response = openai.embeddings.create(input=[text], model=model)
    return response.data[0].embedding

# %%
# Function to Perform vector search
def vector_search(query_text, index, abstracts, top_k=5):
    query_embedding = np.array(get_embedding(query_text)).reshape(1, -1)
    _, top_indices = index.search(query_embedding, top_k)
    return [(abstracts[i], i) for i in top_indices[0]]

# %%
# Search Scopus
MOF_NAME = "PCN-46"  # Change to the desired MOF
papers_df = search_scopus(MOF_NAME, count=500)
papers_df
# Out:
# Warning: Could not find 500 papers. Returning 1 instead.
#   title               abstract  doi
# 0        No abstract available  N/A
